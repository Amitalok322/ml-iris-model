# %%
import pandas as pd

# %%
iris=pd.read_csv('iris.csv')

# %%
iris.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5c93502afc24> in <cell line: 1>()
# ----> 1 iris.head()
#
# NameError: name 'iris' is not defined

# %%
iris['sepal width (cm)']>4
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: sepal width (cm), Length: 150, dtype: bool

# %%
iris[iris['sepal width (cm)']>4]
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 15                5.7               4.4                1.5               0.4
# 32                5.2               4.1                1.5               0.1
# 33                5.5               4.2                1.4               0.2
#
#          target
# 15  Iris-setosa
# 32  Iris-setosa
# 33  Iris-setosa

# %%
iris[iris['petal length (cm)']>1]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#              target
# ...

# %%
iris[iris['petal width (cm)']>2]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 102                7.1               3.0                5.9               2.1
# 104                6.5               3.0                5.8               2.2
# 105                7.6               3.0                6.6               2.1
# 109                7.2               3.6                6.1               2.5
# 112                6.8               3.0                5.5               2.1
# 114                5.8               2.8                5.1               2.4
# 115                6.4               3.2                5.3               2.3
# 117                7.7               3.8                6.7               2.2
# 118                7.7               2.6                6.9               2.3
# 120                6.9               3.2                5.7               2.3
# ...

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
sns.scatterplot(x='sepal length (cm)',y='petal length (cm)',data=iris)
plt.show()

# %%
sns.scatterplot(x='sepal length (cm)',y='petal length (cm)',data=iris,hue='target')
plt.show()

# %%
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#         target
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
y=iris[['sepal length (cm)']]

# %%
x=iris[['sepal width (cm)']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.head()
# Out:
#      sepal width (cm)
# 147               3.0
# 91                3.0
# 96                2.9
# 58                2.9
# 77                3.0

# %%
x_test.head()
# Out:
#      sepal width (cm)
# 48                3.7
# 139               3.1
# 62                2.2
# 3                 3.1
# 72                2.5

# %%
y_train.head()
# Out:
#      sepal length (cm)
# 147                6.5
# 91                 6.1
# 96                 5.7
# 58                 6.6
# 77                 6.7

# %%
y_test.head()
# Out:
#      sepal length (cm)
# 48                 5.3
# 139                6.9
# 62                 6.0
# 3                  4.6
# 72                 6.3

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-78e42af1b936> in <cell line: 1>()
# ----> 1 lr.fit(x_train,y_train)
#
# NameError: name 'lr' is not defined

# %%
y_pred=lr.predict(x_test)

# %%
y_test.head()
# Out:
#      sepal length (cm)
# 48                 5.3
# 139                6.9
# 62                 6.0
# 3                  4.6
# 72                 6.3

# %%
y_pred[0:5]
# Out:
# array([[5.55140286],
#        [5.76245532],
#        [6.079034  ],
#        [5.76245532],
#        [5.97350777]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.7996332042227243

# %%
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#         target
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
y=[['sepal length (cm)']]

# %%
x=[['sepal width (cm)','petal length (cm)','petal width (cm)']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
lr2=LinearRegression()

# %%
lr2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr2.predict(x_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.4805092387427309

# %%
//** covid data sheet **(//

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import datetime as dt
import numpy as np

# %%
df=pd.read_csv('covid_19_india.csv',parse_dates=['Date'],dayfirst=True)

# %%
df.head()
# Out:
#    sno       Date State/UT  Latitude  Longitude  Confirmed  Active  Deaths
# 0    0 2020-01-30   Kerala   10.8505    76.2711          1       1       0
# 1    1 2020-01-31   Kerala   10.8505    76.2711          1       1       0
# 2    2 2020-02-01   Kerala   10.8505    76.2711          2       2       0
# 3    3 2020-02-02   Kerala   10.8505    76.2711          3       3       0
# 4    4 2020-02-03   Kerala   10.8505    76.2711          3       3       0

# %%
df=df[['Date','State/UT','Latitude','Longitude','Confirmed','Active','Deaths']]
df.columns=['date','state','latitude','longitude','confirmed','active','deaths']

# %%
df.head()
# Out:
#         date   state  latitude  longitude  confirmed  active  deaths
# 0 2020-01-30  Kerala   10.8505    76.2711          1       1       0
# 1 2020-01-31  Kerala   10.8505    76.2711          1       1       0
# 2 2020-02-01  Kerala   10.8505    76.2711          2       2       0
# 3 2020-02-02  Kerala   10.8505    76.2711          3       3       0
# 4 2020-02-03  Kerala   10.8505    76.2711          3       3       0

# %%
df.tail()
# Out:
#           date          state  latitude  longitude  confirmed  active  deaths
# 947 2020-04-15      Telengana   18.1124    79.0193        624     507      17
# 948 2020-04-15        Tripura   23.9408    91.9882          2       2       0
# 949 2020-04-15  Uttar Pradesh   26.8467    80.9462        660     605       5
# 950 2020-04-15    Uttarakhand   30.0668    79.0193         37      28       0
# 951 2020-04-15    West Bengal   22.9868    87.8550        213     169       7

# %%
df
# Out:
#           date          state  latitude  longitude  confirmed  active  deaths
# 0   2020-01-30         Kerala   10.8505    76.2711          1       1       0
# 1   2020-01-31         Kerala   10.8505    76.2711          1       1       0
# 2   2020-02-01         Kerala   10.8505    76.2711          2       2       0
# 3   2020-02-02         Kerala   10.8505    76.2711          3       3       0
# 4   2020-02-03         Kerala   10.8505    76.2711          3       3       0
# ..         ...            ...       ...        ...        ...     ...     ...
# 947 2020-04-15      Telengana   18.1124    79.0193        624     507      17
# 948 2020-04-15        Tripura   23.9408    91.9882          2       2       0
# 949 2020-04-15  Uttar Pradesh   26.8467    80.9462        660     605       5
# 950 2020-04-15    Uttarakhand   30.0668    79.0193         37      28       0
# 951 2020-04-15    West Bengal   22.9868    87.8550        213     169       7
#
# [952 rows x 7 columns]

# %%
today=df[df.date=='2020-04-15']

# %%
today
# Out:
#           date                        state  latitude  longitude  confirmed  \
# 919 2020-04-15  Andaman and Nicobar Islands   11.7401    92.6586         11
# 920 2020-04-15               Andhra Pradesh   15.9129    79.7400        483
# 921 2020-04-15            Arunachal Pradesh   28.2180    94.7278          1
# 922 2020-04-15                        Assam   26.2006    92.9376         32
# 923 2020-04-15                        Bihar   25.0961    85.3131         66
# 924 2020-04-15                   Chandigarh   30.7333    76.7794         21
# 925 2020-04-15                 Chhattisgarh   21.2787    81.8661         33
# 926 2020-04-15                        Delhi   28.7041    77.1025       1561
# 927 2020-04-15                          Goa   15.2993    74.1240          7
# 928 2020-04-15                      Gujarat   22.2587    71.1924        650
# 929 2020-04-15                      Haryana   29.0588    76.0856        199
# ...

# %%
today.head()
# Out:
#           date                        state  latitude  longitude  confirmed  \
# 919 2020-04-15  Andaman and Nicobar Islands   11.7401    92.6586         11
# 920 2020-04-15               Andhra Pradesh   15.9129    79.7400        483
# 921 2020-04-15            Arunachal Pradesh   28.2180    94.7278          1
# 922 2020-04-15                        Assam   26.2006    92.9376         32
# 923 2020-04-15                        Bihar   25.0961    85.3131         66
#
#      active  deaths
# 919       1       0
# 920     458       9
# 921       1       0
# 922      31       1
# 923      36       1

# %%
maxcases=today.sort_values(by='confirmed',ascending=False)

# %%
maxcases
# Out:
#           date                        state  latitude  longitude  confirmed  \
# 937 2020-04-15                  Maharashtra   19.7515    75.7139       2687
# 926 2020-04-15                        Delhi   28.7041    77.1025       1561
# 946 2020-04-15                   Tamil Nadu   11.1271    78.6569       1204
# 945 2020-04-15                    Rajasthan   27.0238    74.2179        969
# 936 2020-04-15               Madhya Pradesh   22.9734    78.6569        730
# 949 2020-04-15                Uttar Pradesh   26.8467    80.9462        660
# 928 2020-04-15                      Gujarat   22.2587    71.1924        650
# 947 2020-04-15                    Telengana   18.1124    79.0193        624
# 920 2020-04-15               Andhra Pradesh   15.9129    79.7400        483
# 934 2020-04-15                       Kerala   10.8505    76.2711        387
# 931 2020-04-15            Jammu and Kashmir   33.7782    76.5762        278
# ...

# %%
topstate=maxcases[0:5]
topstate
# Out:
#           date           state  latitude  longitude  confirmed  active  deaths
# 937 2020-04-15     Maharashtra   19.7515    75.7139       2687    2250     178
# 926 2020-04-15           Delhi   28.7041    77.1025       1561    1501      30
# 946 2020-04-15      Tamil Nadu   11.1271    78.6569       1204    1111      12
# 945 2020-04-15       Rajasthan   27.0238    74.2179        969     819       3
# 936 2020-04-15  Madhya Pradesh   22.9734    78.6569        730     629      50

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="state",y="confirmed",data=topstate,hue='state')
plt.show()

# %%
maxdeath=today.sort_values(by='deaths',ascending=False)

# %%
maxdeath
# Out:
#           date                        state  latitude  longitude  confirmed  \
# 937 2020-04-15                  Maharashtra   19.7515    75.7139       2687
# 936 2020-04-15               Madhya Pradesh   22.9734    78.6569        730
# 926 2020-04-15                        Delhi   28.7041    77.1025       1561
# 928 2020-04-15                      Gujarat   22.2587    71.1924        650
# 947 2020-04-15                    Telengana   18.1124    79.0193        624
# 944 2020-04-15                       Punjab   31.1471    75.3412        176
# 946 2020-04-15                   Tamil Nadu   11.1271    78.6569       1204
# 933 2020-04-15                    Karnataka   15.3173    75.7139        260
# 920 2020-04-15               Andhra Pradesh   15.9129    79.7400        483
# 951 2020-04-15                  West Bengal   22.9868    87.8550        213
# 949 2020-04-15                Uttar Pradesh   26.8467    80.9462        660
# ...

# %%
topdeath=maxdeath[0:5]

# %%
topdeath
# Out:
#           date           state  latitude  longitude  confirmed  active  deaths
# 937 2020-04-15     Maharashtra   19.7515    75.7139       2687    2250     178
# 936 2020-04-15  Madhya Pradesh   22.9734    78.6569        730     629      50
# 926 2020-04-15           Delhi   28.7041    77.1025       1561    1501      30
# 928 2020-04-15         Gujarat   22.2587    71.1924        650     563      28
# 947 2020-04-15       Telengana   18.1124    79.0193        624     507      17

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="state",y="deaths",data=topdeath,hue='state')
plt.show()

# %%
mah=df[df.state=='Maharashtra']
mah
# Out:
#           date        state  latitude  longitude  confirmed  active  deaths
# 77  2020-03-09  Maharashtra   19.7515    75.7139          2       2       0
# 89  2020-03-10  Maharashtra   19.7515    75.7139          5       5       0
# 101 2020-03-11  Maharashtra   19.7515    75.7139         10      10       0
# 114 2020-03-12  Maharashtra   19.7515    75.7139         11      11       0
# 127 2020-03-13  Maharashtra   19.7515    75.7139         11      11       0
# 140 2020-03-14  Maharashtra   19.7515    75.7139         14      14       0
# 153 2020-03-15  Maharashtra   19.7515    75.7139         32      32       0
# 167 2020-03-16  Maharashtra   19.7515    75.7139         32      32       0
# 182 2020-03-17  Maharashtra   19.7515    75.7139         39      38       1
# 197 2020-03-18  Maharashtra   19.7515    75.7139         42      41       1
# 215 2020-03-19  Maharashtra   19.7515    75.7139         47      46       1
# ...

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="confirmed",data=mah,color='g')
plt.show()

# %%
ker=df[df.state=='Kerala']

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="confirmed",data=ker,color='r')
plt.show();

# %%
from sklearn.model_selection import train_test_split

# %%
mah

# %%
y=mah['confirmed']
x=mah['date']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
y_train
# Out:
# 844    1574
# 306      74
# 515     216
# 782    1135
# 631     423
# 101      10
# 89        5
# 260      63
# 572     335
# 153      32
# 407     130
# 601     335
# 127      11
# 488     193
# 114      11
# 215      47
# 690     690
# 751    1018
# 77        2
# 544     302
# 235      47
# 283      67
# 434     180
# 875    1761
# 461     186
# Name: confirmed, dtype: int64

# %%
mah
# Out:
#           date        state  latitude  longitude  confirmed  active  deaths
# 77  2020-03-09  Maharashtra   19.7515    75.7139          2       2       0
# 89  2020-03-10  Maharashtra   19.7515    75.7139          5       5       0
# 101 2020-03-11  Maharashtra   19.7515    75.7139         10      10       0
# 114 2020-03-12  Maharashtra   19.7515    75.7139         11      11       0
# 127 2020-03-13  Maharashtra   19.7515    75.7139         11      11       0
# 140 2020-03-14  Maharashtra   19.7515    75.7139         14      14       0
# 153 2020-03-15  Maharashtra   19.7515    75.7139         32      32       0
# 167 2020-03-16  Maharashtra   19.7515    75.7139         32      32       0
# 182 2020-03-17  Maharashtra   19.7515    75.7139         39      38       1
# 197 2020-03-18  Maharashtra   19.7515    75.7139         42      41       1
# 215 2020-03-19  Maharashtra   19.7515    75.7139         47      46       1
# ...

# %%
lr.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# LinearRegression()

# %%
lr.predict(np.array([[2020-7-19]]))
# Out:
# array([[-686348.05064301]])

# %% [markdown]
# wrong prediction

# %%
//logistic regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
color=sns.color_palette()
import sklearn.metrics as metrics

import warnings
warnings.filterwarnings("ignore")

# %%
default=pd.read_csv("default.csv")

# %%
default.head()
# Out:
#    default  student      balance        income
# 0        0        0   729.526495  44361.625074
# 1        0        1   817.180407  12106.134700
# 2        0        0  1073.549164  31767.138947
# 3        0        0   529.250605  35704.493935
# 4        0        0   785.655883  38463.495879

# %%
default.shape
# Out:
# (10000, 4)

# %%
default.describe()
# Out:
#             default       student       balance        income
# count  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.033300      0.294400    835.374886  33516.981876
# std        0.179428      0.455795    483.714985  13336.639563
# min        0.000000      0.000000      0.000000    771.967729
# 25%        0.000000      0.000000    481.731105  21340.462903
# 50%        0.000000      0.000000    823.636973  34552.644802
# 75%        0.000000      1.000000   1166.308386  43807.729272
# max        1.000000      1.000000   2654.322576  73554.233495

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(y=default['balance'])

plt.subplot(1,2,2)
sns.boxplot(y=default['income'])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.countplot(x=default['student'])

plt.subplot(1,2,2)
sns.countplot(x=default['default'])
plt.show()
